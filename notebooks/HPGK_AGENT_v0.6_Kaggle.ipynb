# %% [markdown]
# # HPGK AGENT v0.6 — from-zero training
# This notebook is the GPU lane. It is resumable and never requires your phone/PC to stay on.

# %%
# !pip -q install -r /kaggle/working/HPGK-AGENT-v0.6/ai/requirements.txt

# %%
import os, sys
ROOT="/kaggle/working/HPGK-AGENT-v0.6"
sys.path.insert(0, ROOT+"/ai")
print("CUDA:", __import__("torch").cuda.is_available())

# %%
# !python {ROOT}/ai/kaggle/train_kaggle.py --data_dir {ROOT}/ai/data/raw --epochs 1 --vocab_size 4000 --max_minutes 45

# %% [markdown]
# ## Resume
# For the next session, restore the checkpoint and run with `--resume`.

# %%
# !python {ROOT}/ai/kaggle/train_kaggle.py --data_dir {ROOT}/ai/data/raw --epochs 1 --vocab_size 4000 --max_minutes 45 --resume
